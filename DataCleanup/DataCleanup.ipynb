# %%
import pandas as pd

# %%
#import csv to create gdp df
gdp_df = pd.read_csv("../Raw Data/GDP_dataset/national-gdp.csv")
gdp_df
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  1970
# 1      Albania  ALB  1971
# 2      Albania  ALB  1972
# 3      Albania  ALB  1973
# 4      Albania  ALB  1974
# ...        ...  ...   ...
# 9980  Zimbabwe  ZWE  2013
# 9981  Zimbabwe  ZWE  2014
# 9982  Zimbabwe  ZWE  2015
# 9983  Zimbabwe  ZWE  2016
# 9984  Zimbabwe  ZWE  2017
#
#       Total output-side real GDP  (chained PPPs (2011 US$))
# 0                                            6082047488
# 1                                            6319226368
# 2                                            6580308480
# 3                                            6844453376
# 4                                            7133587456
# ...                                                 ...
# 9980                                        28329809920
# 9981                                        29355759616
# 9982                                        29150750720
# 9983                                        29420449792
# ...

# %%
# rename columns for clean postgres integration
gdp_df = gdp_df.rename(columns={'Entity':'country',
                                 'Code':'country_code',
                                 'Year':'year',
                                 'Total output-side real GDP  (chained PPPs (2011 US$))':'total_gdp(usd)'})
gdp_df
# Out:
#        country country_code  year  total_gdp(usd)
# 0      Albania          ALB  1970      6082047488
# 1      Albania          ALB  1971      6319226368
# 2      Albania          ALB  1972      6580308480
# 3      Albania          ALB  1973      6844453376
# 4      Albania          ALB  1974      7133587456
# ...        ...          ...   ...             ...
# 9980  Zimbabwe          ZWE  2013     28329809920
# 9981  Zimbabwe          ZWE  2014     29355759616
# 9982  Zimbabwe          ZWE  2015     29150750720
# 9983  Zimbabwe          ZWE  2016     29420449792
# 9984  Zimbabwe          ZWE  2017     30940817408
#
# [9985 rows x 4 columns]

# %%
gdp_df.to_csv('cleaned_gdp.csv',header=True,index=False)

# %%
# create array for master list of countries in gdp_df
countries_master = gdp_df2.country.unique()
countries_master
# Out:
# array(['Albania', 'Algeria', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Costa Rica',
#        "Cote d'Ivoire", 'Croatia', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
# ...

# %%
# import csv and create df for master population list (will append list with 2010 and 2018 data from other population csv)
pop_df1 = pd.read_csv("../Raw Data/population_by_country/population-by-country.csv")
pop_df1
# Out:
#            Entity Code  Year  Unnamed: 3
# 0     Afghanistan  AFG  1500   2000000.0
# 1     Afghanistan  AFG  1600   2500000.0
# 2     Afghanistan  AFG  1700   2500000.0
# 3     Afghanistan  AFG  1800   3280000.0
# 4     Afghanistan  AFG  1820   3280000.0
# ...           ...  ...   ...         ...
# 3216     Zimbabwe  ZWE  1960   3751000.0
# 3217     Zimbabwe  ZWE  1970   5514536.0
# 3218     Zimbabwe  ZWE  1980   7169968.0
# 3219     Zimbabwe  ZWE  1990  10156000.0
# 3220     Zimbabwe  ZWE  2000  11820000.0
#
# [3221 rows x 4 columns]

# %%
# rename columns for clean postgres integration
pop_df1 = pop_df1.rename(columns={
    'Entity':'country',
    'Code':'country_code',
    'Year':'year',
    'Unnamed: 3':'population'
})
pop_df1
# Out:
#           country country_code  year  population
# 0     Afghanistan          AFG  1500     2000000
# 1     Afghanistan          AFG  1600     2500000
# 2     Afghanistan          AFG  1700     2500000
# 3     Afghanistan          AFG  1800     3280000
# 4     Afghanistan          AFG  1820     3280000
# ...           ...          ...   ...         ...
# 3216     Zimbabwe          ZWE  1960     3751000
# 3217     Zimbabwe          ZWE  1970     5514536
# 3218     Zimbabwe          ZWE  1980     7169968
# 3219     Zimbabwe          ZWE  1990    10156000
# 3220     Zimbabwe          ZWE  2000    11820000
#
# [3221 rows x 4 columns]

# %%
# change pop data type to integer
pop_df1['population'] = pop_df1['population'].astype(int)
pop_df1
# Out:
#           country country_code  year  population
# 0     Afghanistan          AFG  1500     2000000
# 1     Afghanistan          AFG  1600     2500000
# 2     Afghanistan          AFG  1700     2500000
# 3     Afghanistan          AFG  1800     3280000
# 4     Afghanistan          AFG  1820     3280000
# ...           ...          ...   ...         ...
# 3216     Zimbabwe          ZWE  1960     3751000
# 3217     Zimbabwe          ZWE  1970     5514536
# 3218     Zimbabwe          ZWE  1980     7169968
# 3219     Zimbabwe          ZWE  1990    10156000
# 3220     Zimbabwe          ZWE  2000    11820000
#
# [3221 rows x 4 columns]

# %%
# import csv and create df for supplemental population data (will use 2010 and 2018 data to append pop_df1)
suppl_pop_df = pd.read_csv("../Raw Data/population_growth/API_SP.POP.TOTL_DS2_en_csv_v2_887275.csv")
suppl_pop_df
# Out:
#     Country Code  Country Name     Indicator Name Indicator Code        1960  \
# 0            ABW         Aruba  Population, total    SP.POP.TOTL     54211.0
# 1            AFG   Afghanistan  Population, total    SP.POP.TOTL   8996973.0
# 2            AGO        Angola  Population, total    SP.POP.TOTL   5454933.0
# 3            ALB       Albania  Population, total    SP.POP.TOTL   1608800.0
# 4            AND       Andorra  Population, total    SP.POP.TOTL     13411.0
# ..           ...           ...                ...            ...         ...
# 259          XKX        Kosovo  Population, total    SP.POP.TOTL    947000.0
# 260          YEM   Yemen, Rep.  Population, total    SP.POP.TOTL   5315355.0
# 261          ZAF  South Africa  Population, total    SP.POP.TOTL  17099840.0
# 262          ZMB        Zambia  Population, total    SP.POP.TOTL   3070776.0
# 263          ZWE      Zimbabwe  Population, total    SP.POP.TOTL   3776681.0
#
# ...

# %%
# reorder columns to match other dfs
suppl_pop_df = suppl_pop_df[['Country Name','Country Code','2010','2018']]
suppl_pop_df
# Out:
#      Country Name Country Code        2010        2018
# 0           Aruba          ABW    101669.0    105845.0
# 1     Afghanistan          AFG  29185507.0  37172386.0
# 2          Angola          AGO  23356246.0  30809762.0
# 3         Albania          ALB   2913021.0   2866376.0
# 4         Andorra          AND     84449.0     77006.0
# ..            ...          ...         ...         ...
# 259        Kosovo          XKX   1775680.0   1845300.0
# 260   Yemen, Rep.          YEM  23154855.0  28498687.0
# 261  South Africa          ZAF  51216964.0  57779622.0
# 262        Zambia          ZMB  13605984.0  17351822.0
# 263      Zimbabwe          ZWE  12697723.0  14439018.0
#
# [264 rows x 4 columns]

# %%
# rename columns for clean postgres integration
suppl_pop_df = suppl_pop_df.rename(columns={
    'Country Name':'country',
    'Country Code':'country_code',
    '2010':'2010',
    '2018':'2018'
})
suppl_pop_df
# Out:
#           country country_code        2010        2018
# 0           Aruba          ABW    101669.0    105845.0
# 1     Afghanistan          AFG  29185507.0  37172386.0
# 2          Angola          AGO  23356246.0  30809762.0
# 3         Albania          ALB   2913021.0   2866376.0
# 4         Andorra          AND     84449.0     77006.0
# ..            ...          ...         ...         ...
# 259        Kosovo          XKX   1775680.0   1845300.0
# 260   Yemen, Rep.          YEM  23154855.0  28498687.0
# 261  South Africa          ZAF  51216964.0  57779622.0
# 262        Zambia          ZMB  13605984.0  17351822.0
# 263      Zimbabwe          ZWE  12697723.0  14439018.0
#
# [264 rows x 4 columns]

# %%
# replace country names that don't match with pop_df1
# used excel to run comparison of country names matching country_codes and looked for differences
suppl_pop_df = suppl_pop_df.replace({
    "Bahamas, The":"Bahamas",
    "Brunei Darussalam":"Brunei",
    "Cabo Verde":"Cape Verde",
    "Congo, Rep.":"Congo",
    "Congo, Dem. Rep.":"Democratic Republic of Congo",
    "Egypt, Arab Rep.":"Egypt",
    "Gambia, The":"Gambia",
    "Hong Kong SAR, China":"Hong Kong",
    "Iran, Islamic Rep.":"Iran",
    "Kyrgyz Republic":"Kyrgyzstan",
    "Lao PDR":"Laos",
    "Macao SAR, China":"Macao",
    "North Macedonia":"Macedonia",
    "West Bank and Gaza":"Palestine",
    "Russian Federation":"Russia",
    "St. Kitts and Nevis":"Saint Kitts and Nevis",
    "St. Lucia":"Saint Lucia",
    "St. Vincent and the Grenadines":"SAint Vincent and the Grenadines",
    "Slovak Republic":"Slovakia",
    "Korea, Rep.":"South Korea",
    "Eswatini":"Swaziland",
    "Syrian Arab Republic":"Syria",
    "Venezuela, RB":"Venezuela",
    "Yemen, Rep.":"Yemen"
})
suppl_pop_df
# Out:
#           country country_code        2010        2018
# 0           Aruba          ABW    101669.0    105845.0
# 1     Afghanistan          AFG  29185507.0  37172386.0
# 2          Angola          AGO  23356246.0  30809762.0
# 3         Albania          ALB   2913021.0   2866376.0
# 4         Andorra          AND     84449.0     77006.0
# ..            ...          ...         ...         ...
# 259        Kosovo          XKX   1775680.0   1845300.0
# 260         Yemen          YEM  23154855.0  28498687.0
# 261  South Africa          ZAF  51216964.0  57779622.0
# 262        Zambia          ZMB  13605984.0  17351822.0
# 263      Zimbabwe          ZWE  12697723.0  14439018.0
#
# [264 rows x 4 columns]

# %%
life_df = pd.read_csv("../Raw Data/life_expectancy/life-expectancy.csv")
life_df
# Out:
#             Entity Code  Year  Life expectancy (years)
# 0      Afghanistan  AFG  1950                   27.638
# 1      Afghanistan  AFG  1951                   27.878
# 2      Afghanistan  AFG  1952                   28.361
# 3      Afghanistan  AFG  1953                   28.852
# 4      Afghanistan  AFG  1954                   29.350
# ...            ...  ...   ...                      ...
# 19023     Zimbabwe  ZWE  2015                   59.534
# 19024     Zimbabwe  ZWE  2016                   60.294
# 19025     Zimbabwe  ZWE  2017                   60.812
# 19026     Zimbabwe  ZWE  2018                   61.195
# 19027     Zimbabwe  ZWE  2019                   61.490
#
# [19028 rows x 4 columns]

# %%
life_df = life_df.dropna()
life_df
# Out:
#             Entity Code  Year  Life expectancy (years)
# 0      Afghanistan  AFG  1950                   27.638
# 1      Afghanistan  AFG  1951                   27.878
# 2      Afghanistan  AFG  1952                   28.361
# 3      Afghanistan  AFG  1953                   28.852
# 4      Afghanistan  AFG  1954                   29.350
# ...            ...  ...   ...                      ...
# 19023     Zimbabwe  ZWE  2015                   59.534
# 19024     Zimbabwe  ZWE  2016                   60.294
# 19025     Zimbabwe  ZWE  2017                   60.812
# 19026     Zimbabwe  ZWE  2018                   61.195
# 19027     Zimbabwe  ZWE  2019                   61.490
#
# [18445 rows x 4 columns]

# %%
life_df.to_csv('cleaned_life_exp.csv',header=True,index=False)

# %%
continent_df = pd.read_csv("../Raw Data/population_growth/API_SP.POP.TOTL_DS2_en_csv_v2_887275.csv")
